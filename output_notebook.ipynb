# %% [markdown]
# # **Human Inspired Genetic Algorithms**

# %% [markdown]
# ## Environment Set Up

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils.environment import Environment 
from utils.evaluation_metrics import FinalEvaluationMetrics

from multi_agent_ga import simulate_evacuation, greedy_algorithm

city = Environment(city_name="super_small_city_graph")

# %% [markdown]
# ## Basic Genetic Algorithm

# %%
solution_basic, evaluation_basic = simulate_evacuation(
    city=city,
    num_agents=10,
    population_size=50,
    algorithm_seed=29,
    max_evolutions=10,
    simulation_params={"congestion": True, "walking": True, "panic": False},
)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#  City: super_small_city_graph | Population size: 50 | Walking Speed: 1.8
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Evolution    1 | best fit: 0.387 | avg fit: 0.309 | worst fit: 0.272 | avg path: 11.078 | congestion: 0.624 | exit utilisation: 0.207
# Evolution    2 | best fit: 0.405 | avg fit: 0.323 | worst fit: 0.294 | avg path: 10.286 | congestion: 0.624 | exit utilisation: 0.207
# Evolution    3 | best fit: 0.405 | avg fit: 0.328 | worst fit: 0.302 | avg path: 9.994 | congestion: 0.624 | exit utilisation: 0.197
# Evolution    4 | best fit: 0.405 | avg fit: 0.337 | worst fit: 0.313 | avg path: 9.680 | congestion: 0.624 | exit utilisation: 0.211
# ...

# %% [markdown]
# ## Human Inspired Genetic Algorithm

# %%
human_ga_params = {"congestion": True, "walking": True, "panic": True}
solution_human, evaluation_human = simulate_evacuation(
    city=city,
    num_agents=10,
    population_size=50,
    algorithm_seed=29,
    max_evolutions=50,
    simulation_params=human_ga_params,
)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#  City: super_small_city_graph | Population size: 50 | Walking Speed: 1.8
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Evolution    1 | best fit: 0.387 | avg fit: 0.298 | worst fit: 0.257 | avg path: 11.984 | congestion: 0.624 | exit utilisation: 0.195
# Evolution    2 | best fit: 0.387 | avg fit: 0.306 | worst fit: 0.268 | avg path: 11.658 | congestion: 0.624 | exit utilisation: 0.211
# Evolution    3 | best fit: 0.387 | avg fit: 0.313 | worst fit: 0.276 | avg path: 11.104 | congestion: 0.624 | exit utilisation: 0.202
# Evolution    4 | best fit: 0.387 | avg fit: 0.320 | worst fit: 0.289 | avg path: 10.920 | congestion: 0.624 | exit utilisation: 0.203
# ...

# %% [markdown]
# ## Greedy Algorithm

# %%
greedy_params = {"congestion": True, "walking": True, "panic": True}
greedy_solution = greedy_algorithm(
    city=city,
    num_agents=10,
    simulation_params=greedy_params,
)

# %%
final_greedy = FinalEvaluationMetrics(solution=greedy_solution, chromosome=False, params=greedy_params)
final_greedy.score()
# Out:
# Average path length: 3.200 | Total path length: 4.000 | Average duration: 7.600 | Congestion delays: 1.800 | Exit utilisation: 0.300

# %%
final_human = FinalEvaluationMetrics(solution=solution_human, chromosome=True, params=human_ga_params)
final_human.score()
# Out:
# Average path length: 8.000 | Total path length: 22.000 | Average duration: 17.900 | Congestion delays: 0.600 | Exit utilisation: 0.000
