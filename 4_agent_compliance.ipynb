# %% [markdown]
# # Agent Compliance
# This notebook looks at the rate of compliance across our agents. How does the influence of greedy agents into the genetic algorithm solution impact the performance?
